# %%
import tensorflow as tf


physical_devices = tf.config.list_physical_devices("GPU")
print(physical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# https://www.learndatasci.com/tutorials/hands-on-transfer-learning-keras/#:~:text=In%20the%202014%20ImageNet%20Classification,present%20in%20our%20Food%20dataset.

# %%
import os
from keras.models import Model
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img,img_to_array
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras import layers, models, Model, optimizers
from PIL import ImageFile,Image
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet import ResNet50


import datetime
import time
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
train_data_dir ='D:/TQ/Fruits360/fruits-360_dataset/fruits-360/Training/'
test_data_dir = 'D:/TQ/Fruits360/fruits-360_dataset/fruits-360/Test/'

total_classes = sorted(os.listdir(train_data_dir))
print(total_classes)
# Out:
# ['Apple Braeburn', 'Apple Crimson Snow', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Pink Lady', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow 1', 'Apple Red Yellow 2', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Lady Finger', 'Banana Red', 'Beetroot', 'Blueberry', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cauliflower', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Chestnut', 'Clementine', 'Cocos', 'Corn', 'Corn Husk', 'Cucumber Ripe', 'Cucumber Ripe 2', 'Dates', 'Eggplant', 'Fig', 'Ginger Root', 'Granadilla', 'Grape Blue', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grape White 3', 'Grape White 4', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mango Red', 'Mangostan', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Nectarine Flat', 'Nut Forest', 'Nut Pecan', 'Onion Red', 'Onion Red Peeled', 'Onion White', 'Orange', 'Papaya', 'Passion Fruit', 'Peach', 'Peach 2', 'Peach Flat', 'Pear', 'Pear 2', 'Pear Abate', 'Pear Forelle', 'Pear Kaiser', 'Pear Monster', 'Pear Red', 'Pear Stone', 'Pear Williams', 'Pepino', 'Pepper Green', 'Pepper Orange', 'Pepper Red', 'Pepper Yellow', 'Physalis', 'Physalis with Husk', 'Pineapple', 'Pineapple Mini', 'Pitahaya Red', 'Plum', 'Plum 2', 'Plum 3', 'Pomegranate', 'Pomelo Sweetie', 'Potato Red', 'Potato Red Washed', 'Potato Sweet', 'Potato White', 'Quince', 'Rambutan', 'Raspberry', 'Redcurrant', 'Salak', 'Strawberry', 'Strawberry Wedge', 'Tamarillo', 'Tangelo', 'Tomato 1', 'Tomato 2', 'Tomato 3', 'Tomato 4', 'Tomato Cherry Red', 'Tomato Heart', 'Tomato Maroon', 'Tomato Yellow', 'Tomato not Ripened', 'Walnut', 'Watermelon']

# %%
BATCH_SIZE = 64

train_generator =ImageDataGenerator( validation_split=0.15,
                                    #rescale=1./255,
                                   preprocessing_function=preprocess_input )

test_generator = ImageDataGenerator(preprocessing_function=preprocess_input) # MobileNetV2

# %%
traingen = train_generator.flow_from_directory(train_data_dir,
                                               target_size=(100, 100),
                                               class_mode='categorical',
                                               classes=total_classes,
                                               subset='training',
                                               batch_size=BATCH_SIZE, 
                                               shuffle=True,
                                               seed=42)

validgen = train_generator.flow_from_directory(train_data_dir,
                                               target_size=(100, 100),
                                               class_mode='categorical',
                                               classes=total_classes,
                                               subset='validation',
                                               batch_size=BATCH_SIZE,
                                               shuffle=True,
                                               seed=42)

testgen = test_generator.flow_from_directory(test_data_dir,
                                             target_size=(100, 100),
                                             class_mode=None,
                                             classes=total_classes,
                                             batch_size=1,
                                             shuffle=False,
                                             seed=42)
# Out:
# Found 57612 images belonging to 131 classes.
# Found 10080 images belonging to 131 classes.
# Found 22688 images belonging to 131 classes.

# %%
import matplotlib.pyplot as plt

for _ in range(5):
    img, label = traingen.next()
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0].astype(np.uint8))
    plt.show()
# Out:
# (64, 100, 100, 3)
# (64, 100, 100, 3)
# (64, 100, 100, 3)
# (64, 100, 100, 3)
# (64, 100, 100, 3)

# %%
# Model Creation
def create_model(input_shape, n_classes, optimizer='rmsprop', fine_tune=0):
    """
    Compiles a model integrated with VGG16 pretrained layers
    
    input_shape: tuple - the shape of input images (width, height, channels)
    n_classes: int - number of classes for the output layer
    optimizer: string - instantiated optimizer to use for training. Defaults to 'RMSProp'
    fine_tune: int - The number of pre-trained layers to unfreeze.
                If set to 0, all pretrained layers will freeze during training
    """
    
    # Pretrained convolutional layers are loaded using the Imagenet weights.
    # Include_top is set to False, in order to exclude the model's fully-connected layers.
    conv_base =  tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(100,100,3),
                   pooling='avg',classes=131,
                   weights='imagenet')
    
    # Defines how many layers to freeze during training.
    # Layers in the convolutional base are switched from trainable to non-trainable
    # depending on the size of the fine-tuning parameter.
    if fine_tune > 0:
        for layer in conv_base.layers[:-fine_tune]:
            layer.trainable = False
    else:
        for layer in conv_base.layers:
            layer.trainable = False

    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    top_model = conv_base.output
     
    top_model = Flatten(name="flatten")(top_model)
    top_model = Dense(4096, activation='relu')(top_model)
    top_model = Dense(1072, activation='relu')(top_model)
    top_model = Dropout(0.2)(top_model)
    
    output_layer = Dense(n_classes, activation='softmax')(top_model)
    
    # Group the convolutional base and new fully-connected layers into a Model object.
    model = Model(inputs=conv_base.input, outputs=output_layer)

    # Compiles the model for training.
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
# Use a smaller learning rate
input_shape = (100,100, 3)
optim_1 = Adam(learning_rate=0.001)
n_classes=len(total_classes)

n_steps = traingen.samples // BATCH_SIZE
n_val_steps = validgen.samples // BATCH_SIZE
n_epochs = 20

#optim_2 = Adam(lr=0.0001)

# First we'll train the model without Fine-tuning
resnet_model_ft = create_model(input_shape, n_classes, optim_1, fine_tune=0)

# %%
from livelossplot.inputs.keras import PlotLossesCallback

plot_loss_1 = PlotLossesCallback()
csv_logger = CSVLogger('D:/TQ/Fruits360/ReNetNet_Model_July_25_20_Epochs.csv', separator=',')

# ModelCheckpoint callback - save best weights
tl_checkpoint_1 = ModelCheckpoint(filepath='D:/TQ/Fruits360/ResNet_Model_NoImageAugmentation_20_Epochs.h5',
                                  save_best_only=True,
                                  verbose=1)

# EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')

# %%
resnet_model_ft.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 50, 50, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 25, 25, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 25, 25, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 25, 25, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 25, 25, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 13, 13, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 13, 13, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 13, 13, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 13, 13, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 13, 13, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 13, 13, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 7, 7, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  dense (Dense)                  (None, 4096)         8392704     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1072)         4391984     ['dense[0][0]']
#
#  dropout (Dropout)              (None, 1072)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 131)          140563      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 36,512,963
# Trainable params: 12,925,251
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# %%time

plot_loss_2 = PlotLossesCallback()

# Retrain model with fine-tuning
resnet_ft_history = resnet_model_ft.fit(traingen,
                                  batch_size=BATCH_SIZE,
                                  epochs=n_epochs,
                                  validation_data=validgen,
                                  steps_per_epoch=n_steps, 
                                  validation_steps=n_val_steps,
                                  callbacks=[csv_logger,tl_checkpoint_1, early_stop, plot_loss_2],
                                  verbose=1)
# Out:
# accuracy
# 	training         	 (min:    0.952, max:    0.999, cur:    0.998)
# 	validation       	 (min:    0.958, max:    0.992, cur:    0.972)
# Loss
# 	training         	 (min:    0.014, max:    0.203, cur:    0.021)
# 	validation       	 (min:    0.028, max:    0.364, cur:    0.276)
# 900/900 [==============================] - 241s 268ms/step - loss: 0.0213 - accuracy: 0.9980 - val_loss: 0.2759 - val_accuracy: 0.9720
# CPU times: total: 1h 8min 53s
# Wall time: 55min 47s

# %%
resnet_model_ft.save("D:/TQ/Fruits360/Results/ResNet_Model_July_25_20.h5")

# %%
from tensorflow.keras import models
resnet_model_ft = models.load_model('D:/TQ/Fruits360/Results/ResNet_Model_July_25_20.h5')

# %%
# Generate predictions
#vgg_model_ft.load_weights('tl_model_v1.weights.best.hdf5') # initialize the best trained weights

resnet_preds_ft = resnet_model_ft.predict(testgen)
resnet_pred_classes_ft = np.argmax(resnet_preds_ft, axis=1)
# Out:
# 22688/22688 [==============================] - 702s 31ms/step

# %%
true_classes = testgen.classes

resnet_acc_ft = accuracy_score(true_classes, resnet_pred_classes_ft)

print("ResNet Model Accuracy without Fine-Tuning: {:.2f}%".format(resnet_acc_ft * 100))
# Out:
# ResNet Model Accuracy without Fine-Tuning: 96.43%

# %%
acc = resnet_ft_history.history['accuracy']
val_acc = resnet_ft_history.history['val_accuracy']
loss = resnet_ft_history.history['loss']
val_loss = resnet_ft_history.history['val_loss']
epochs = range(1,len(acc)+1)
plt.figure()
plt.plot(epochs, acc, 'b', label = 'Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training accuracy')
plt.legend()
plt.savefig('D:/TQ/Fruits360/Results/MobileNet_50_Epochs_Accuracy.jpg')
plt.figure()
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('D:/TQ/Fruits360/Results/MobileNet_50_Epochs_Loss.jpg')

# %%
# Confusion Matrix
start = datetime.datetime.now()
Y_pred = resnet_preds_ft
y_pred = np.argmax(Y_pred, axis=1)
cm = confusion_matrix(testgen.classes, y_pred)
print(cm)

end= datetime.datetime.now()
print("Testing End at: ", end)
elapsed= end-start
print ("Time: ", elapsed)
# Out:
# [[164   0   0 ...   0   0   0]
#  [  0 148   0 ...   0   0   0]
#  [  0   0 160 ...   0   0   0]
#  ...
#  [  0   0   0 ... 158   0   0]
#  [  0   0   0 ...   0 249   0]
#  [  0   0   0 ...   0   0 157]]
# Testing End at:  2022-07-28 03:12:24.631081
# Time:  0:00:00.005059

# %%
report = classification_report(testgen.classes, y_pred, target_names=total_classes)
print(report)
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       0.81      1.00      0.90       164
#  Apple Crimson Snow       0.84      1.00      0.91       148
#      Apple Golden 1       1.00      1.00      1.00       160
#      Apple Golden 2       1.00      0.94      0.97       164
#      Apple Golden 3       0.89      0.96      0.92       161
#  Apple Granny Smith       0.90      0.98      0.94       164
#     Apple Pink Lady       0.79      0.93      0.85       152
#         Apple Red 1       0.94      0.67      0.78       164
#         Apple Red 2       0.84      0.76      0.80       164
#         Apple Red 3       0.99      0.92      0.95       144
# Apple Red Delicious       1.00      1.00      1.00       166
#  Apple Red Yellow 1       0.98      0.88      0.93       164
#  Apple Red Yellow 2       1.00      1.00      1.00       219
#             Apricot       1.00      1.00      1.00       164
#             Avocado       1.00      1.00      1.00       143
#        Avocado ripe       1.00      1.00      1.00       166
#              Banana       1.00      1.00      1.00       166
#  Banana Lady Finger       0.96      0.99      0.98       152
#          Banana Red       1.00      0.96      0.98       166
#            Beetroot       0.94      0.77      0.85       150
#           Blueberry       1.00      1.00      1.00       154
#        Cactus fruit       0.89      1.00      0.94       166
#        Cantaloupe 1       1.00      1.00      1.00       164
#        Cantaloupe 2       0.99      1.00      1.00       164
#           Carambula       1.00      0.90      0.95       166
#         Cauliflower       1.00      0.98      0.99       234
#            Cherry 1       1.00      0.99      0.99       164
#            Cherry 2       1.00      1.00      1.00       246
#      Cherry Rainier       1.00      0.83      0.91       246
#    Cherry Wax Black       1.00      1.00      1.00       164
#      Cherry Wax Red       1.00      1.00      1.00       164
#   Cherry Wax Yellow       1.00      1.00      1.00       164
#            Chestnut       1.00      1.00      1.00       153
#          Clementine       1.00      0.74      0.85       166
#               Cocos       1.00      0.99      1.00       166
#                Corn       1.00      0.69      0.82       150
#           Corn Husk       0.93      0.73      0.82       154
#       Cucumber Ripe       1.00      1.00      1.00       130
#     Cucumber Ripe 2       1.00      1.00      1.00       156
#               Dates       0.99      1.00      1.00       166
#            Eggplant       1.00      0.63      0.78       156
#                 Fig       0.93      1.00      0.96       234
#         Ginger Root       0.92      1.00      0.96        99
#          Granadilla       1.00      1.00      1.00       166
#          Grape Blue       1.00      1.00      1.00       328
#          Grape Pink       0.96      1.00      0.98       164
#         Grape White       0.97      0.70      0.81       166
#       Grape White 2       0.82      1.00      0.90       166
#       Grape White 3       1.00      0.99      1.00       164
#       Grape White 4       0.98      1.00      0.99       158
#     Grapefruit Pink       0.99      1.00      1.00       166
#    Grapefruit White       1.00      1.00      1.00       164
#               Guava       0.98      1.00      0.99       166
#            Hazelnut       1.00      1.00      1.00       157
#         Huckleberry       1.00      1.00      1.00       166
#                Kaki       1.00      0.99      1.00       166
#                Kiwi       1.00      0.99      1.00       156
#            Kohlrabi       0.81      1.00      0.90       157
#            Kumquats       1.00      1.00      1.00       166
#               Lemon       0.98      1.00      0.99       164
#         Lemon Meyer       1.00      1.00      1.00       166
#               Limes       1.00      1.00      1.00       166
#              Lychee       1.00      0.99      1.00       166
#           Mandarine       1.00      1.00      1.00       166
#               Mango       1.00      1.00      1.00       166
#           Mango Red       0.73      1.00      0.84       142
#           Mangostan       0.92      1.00      0.96       102
#            Maracuja       1.00      1.00      1.00       166
#  Melon Piel de Sapo       1.00      1.00      1.00       246
#            Mulberry       1.00      1.00      1.00       164
#           Nectarine       0.99      0.90      0.94       164
#      Nectarine Flat       0.99      1.00      1.00       160
#          Nut Forest       1.00      1.00      1.00       218
#           Nut Pecan       1.00      1.00      1.00       178
#           Onion Red       0.82      1.00      0.90       150
#    Onion Red Peeled       1.00      1.00      1.00       155
#         Onion White       0.93      0.67      0.78       146
#              Orange       1.00      1.00      1.00       160
#              Papaya       0.99      0.98      0.98       164
#       Passion Fruit       1.00      0.99      0.99       166
#               Peach       0.91      1.00      0.95       164
#             Peach 2       1.00      1.00      1.00       246
#          Peach Flat       0.98      0.99      0.98       164
#                Pear       0.96      0.91      0.93       164
#              Pear 2       1.00      0.72      0.84       232
#          Pear Abate       1.00      1.00      1.00       166
#        Pear Forelle       0.84      1.00      0.91       234
#         Pear Kaiser       1.00      0.95      0.97       102
#        Pear Monster       1.00      1.00      1.00       166
#            Pear Red       1.00      1.00      1.00       222
#          Pear Stone       0.94      0.99      0.96       237
#       Pear Williams       1.00      1.00      1.00       166
#              Pepino       0.82      1.00      0.90       166
#        Pepper Green       1.00      1.00      1.00       148
#       Pepper Orange       0.99      1.00      1.00       234
#          Pepper Red       0.85      1.00      0.92       222
#       Pepper Yellow       1.00      0.92      0.96       222
#            Physalis       0.98      1.00      0.99       164
#  Physalis with Husk       0.83      1.00      0.91       164
#           Pineapple       0.97      1.00      0.99       166
#      Pineapple Mini       1.00      1.00      1.00       163
#        Pitahaya Red       1.00      1.00      1.00       166
#                Plum       0.97      0.95      0.96       151
#              Plum 2       1.00      1.00      1.00       142
#              Plum 3       0.96      1.00      0.98       304
#         Pomegranate       0.96      0.99      0.98       164
#      Pomelo Sweetie       1.00      1.00      1.00       153
#          Potato Red       1.00      0.91      0.95       150
#   Potato Red Washed       1.00      0.76      0.86       151
#        Potato Sweet       0.93      0.99      0.96       150
#        Potato White       0.97      1.00      0.99       150
#              Quince       1.00      1.00      1.00       166
#            Rambutan       1.00      1.00      1.00       164
#           Raspberry       0.99      1.00      1.00       166
#          Redcurrant       1.00      1.00      1.00       164
#               Salak       1.00      1.00      1.00       162
#          Strawberry       1.00      1.00      1.00       164
#    Strawberry Wedge       1.00      1.00      1.00       246
#           Tamarillo       0.87      1.00      0.93       166
#             Tangelo       0.88      0.99      0.93       166
#            Tomato 1       1.00      0.85      0.92       246
#            Tomato 2       0.97      1.00      0.99       225
#            Tomato 3       0.88      1.00      0.93       246
#            Tomato 4       1.00      1.00      1.00       160
#   Tomato Cherry Red       1.00      1.00      1.00       164
#        Tomato Heart       0.99      0.87      0.93       228
#       Tomato Maroon       1.00      1.00      1.00       127
#       Tomato Yellow       0.88      1.00      0.94       153
#  Tomato not Ripened       1.00      1.00      1.00       158
#              Walnut       1.00      1.00      1.00       249
#          Watermelon       0.95      1.00      0.98       157
#
#            accuracy                           0.96     22688
#           macro avg       0.97      0.96      0.96     22688
#        weighted avg       0.97      0.96      0.96     22688

# %%
file_names=testgen.filenames  # save list of test files names to be used later
tlabels=testgen.labels # save test labels to be used later
class_dict=testgen.class_indices
# code below determines test batch size and test steps
# so you go through the test images exactly once
length=len(file_names) # determine number of images
b_max=80 # set maximum batch size you will allow
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=b_max],reverse=True)[0]
test_steps=int(length/BATCH_SIZE)
# make predictions
preds=Y_pred
new_dict={} 
for key in class_dict: # set key in new_dict to value in class_dict and value in new_dict to key in class_dict
    value=class_dict[key]
    new_dict[value]=key
error_list=[] # empty list to store if the prediction was correct or not
true_predictions = {}
false_predictions = {}
error_file_list=[]
a = b = 1
for i, p in enumerate(preds):
    pred_index=np.argmax(p) # get the index that has the highest probability
    if pred_index == tlabels[i]: #correct predictions
      true_predictions[a] = {}
      true_predictions[a]['PredictedClass'] = new_dict[pred_index]
      true_predictions[a]['TrueClass'] = new_dict[tlabels[i]]
      true_predictions[a]['FileName'] = file_names[i]
      true_predictions[a]['Status'] = 'No'
      error_list.append('No')
      a+=1
    else:
      error_list.append('Yes')
      false_predictions[b] = {}
      false_predictions[b]['PredictedClass'] = new_dict[pred_index]
      false_predictions[b]['TrueClass'] = new_dict[tlabels[i]]
      false_predictions[b]['FileName'] = file_names[i]
      false_predictions[b]['Status'] = 'Yes'
      b+=1
      #print(f'    {pred_class:10s}       {true_class:10s}    {file:25s}   {error_status:10s}')  
      
print("Total Images: ",len(error_list))
print("True Predictions: ",len(true_predictions))
print("False Predictions: ",len(false_predictions))
# Out:
# Total Images:  22688
# True Predictions:  157
# False Predictions:  22531

# %%
print("---------------------True Predictions--------------------\n")
print('PREDICTED CLASS            TRUE CLASS         FILENAME                        STATUS' ) # adjust spacing based on your class names
for i in range(1,1150):
  pred_class = true_predictions[i]['PredictedClass']  # find the predicted class based on the index
  true_class = true_predictions[i]['TrueClass'] # use the test label to get the true class of the test file
  file = true_predictions[i]['FileName']
  status = true_predictions[i]['Status']
  print(f'    {pred_class:10s}       {true_class:10s}    {file:25s}   {status:10s}')
# Out:
# ---------------------True Predictions--------------------
#
# PREDICTED CLASS            TRUE CLASS         FILENAME                        STATUS
#     Hazelnut         Hazelnut      Hazelnut\12_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\155_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\171_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\173_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\175_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\176_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\187_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\188_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\189_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\190_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\191_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\192_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\193_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\194_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\195_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\196_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\197_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\198_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\199_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\200_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\201_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\202_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\203_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\204_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\205_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\206_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\207_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\209_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\211_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\214_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\215_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\216_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\217_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\220_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\221_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\222_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\223_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\224_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\225_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\226_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\227_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\228_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\229_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\230_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\231_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\232_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\233_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\234_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\236_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\29_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\306_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\309_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\30_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\31_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\32_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\34_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\38_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\44_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\49_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\53_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\54_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\59_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\62_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\63_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\64_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\68_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\69_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\76_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\77_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\78_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\79_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\81_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\82_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\84_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\85_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\86_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\87_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\90_100.jpg         No
#     Hazelnut         Hazelnut      Hazelnut\r_10_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_11_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_12_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_136_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_139_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_13_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_140_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_145_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_148_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_149_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_14_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_150_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_151_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_152_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_153_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_154_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_155_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_156_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_157_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_158_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_159_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_15_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_160_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_161_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_162_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_163_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_164_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_165_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_166_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_167_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_168_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_169_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_16_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_170_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_175_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_17_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_20_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_24_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_25_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_26_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_27_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_28_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_291_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_29_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_303_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_304_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_305_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_306_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_307_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_308_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_309_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_30_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_310_100.jpg      No
#     Hazelnut         Hazelnut      Hazelnut\r_31_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_32_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_33_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_34_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_35_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_36_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_37_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_38_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_39_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_3_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_40_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_41_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_42_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_43_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_45_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_46_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_47_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_48_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_49_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_4_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_50_100.jpg       No
#     Hazelnut         Hazelnut      Hazelnut\r_5_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_6_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_7_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_8_100.jpg        No
#     Hazelnut         Hazelnut      Hazelnut\r_9_100.jpg        No
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       2 print('PREDICTED CLASS            TRUE CLASS         FILENAME                        STATUS' ) # adjust spacing based on your class names
#       3 for i in range(1,1150):
# ----> 4   pred_class = true_predictions[i]['PredictedClass']  # find the predicted class based on the index
#       5   true_class = true_predictions[i]['TrueClass'] # use the test label to get the true class of the test file
#       6   file = true_predictions[i]['FileName']
#
# KeyError: 158
